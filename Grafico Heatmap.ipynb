# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

colunasEnem=['NU_IDADE', 'TP_SEXO','TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 
             'IN_TREINEIRO','TP_DEPENDENCIA_ADM_ESC','TP_LOCALIZACAO_ESC',
            'NU_NOTA_CN','NU_NOTA_LC','NU_NOTA_CH','NU_NOTA_MT','TP_LINGUA','Q005','Q006']

enem = pd.read_csv('MICRODADOS_ENEM_2018.csv', sep=";", encoding='ISO-8859-1', usecols=colunasEnem)

enem.rename({'TP_ESCOLA':'TIPO DE ESCOLA','NU_IDADE':'IDADE','TP_ESTADO_CIVIL':'ESTADO CIVIL','TP_SEXO':'SEXO',
             'TP_COR_RACA':'COR RACIAL','TP_ST_CONCLUSAO':'SITUAÇÃO ENSINO MEDIO',
             'TP_ANO_CONCLUIU':'ANO DE CONCLUSÃO DO EM','IN_TREINEIRO':'TREINEIRO',
             'TP_DEPENDENCIA_ADM_ESC':'DEPENDENCIA ADMNISTRATIVA DA ESCOLA',
             'TP_LOCALIZACAO_ESC':'LOCALIZAÇÃO DA ESCOLA','NU_NOTA_CN':'NOTA CIÊNCIA DA NATUREZA',
             'NU_NOTA_LC':'NOTA LINGUAGENS E CÓDIGOS',
             'NU_NOTA_CH':'NOTA CIÊNCIAS HUMANAS','NU_NOTA_MT':'NOTA MATEMÁTICA',
             'TP_LINGUA':'LINGUA ESTRANGEIRA','Q005':'PESSOAS QUE MORAM NA RESIDÊNCIA'},
           inplace = True, axis='columns')

sns.heatmap(enem.corr(),annot=False,fmt="d")
enem.head()
# Out:
#    IDADE SEXO  ESTADO CIVIL  COR RACIAL  SITUAÇÃO ENSINO MEDIO  \
# 0   44.0    M           1.0           1                      2
# 1   23.0    F           0.0           3                      1
# 2   23.0    F           0.0           1                      1
# 3   26.0    F           0.0           3                      1
# 4   20.0    M           0.0           0                      2
#
#    ANO DE CONCLUSÃO DO EM  TIPO DE ESCOLA  TREINEIRO  \
# 0                       0               2          0
# 1                       5               1          0
# 2                       3               1          0
# 3                       8               1          0
# 4                       0               2          0
#
#    DEPENDENCIA ADMNISTRATIVA DA ESCOLA  LOCALIZAÇÃO DA ESCOLA  \
# 0                                  2.0                    1.0
# 1                                  NaN                    NaN
# 2                                  NaN                    NaN
# ...
