# %%
import pandas as pd
import seaborn as sns

colunasEnem=['NU_IDADE']
enem = pd.read_csv('MICRODADOS_ENEM_2018.csv', sep=";", encoding='ISO-8859-1', usecols= colunasEnem)

enem.rename({'NU_IDADE':'IDADE'},inplace = True, axis='columns')

sns.distplot(enem['IDADE'], kde=False)
